# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from utility.common import (
    create_embedding_model,
    create_vector_store,
    load_project_env,
)
from utility.ingestion import (
    compute_file_hash,
    embedding_ingestion_vector_db,
    extract_metadata_from_filename,
    extract_pdf_page_wise,
    processed_hash,
    run_pipeline_tests,
)

# %%
load_project_env(PROJECT_ROOT)

DATA_DIRECTORY = (
    PROJECT_ROOT.parent
    / "Agentic-RAG-with-LangGraph-and-Ollama-main"
    / "12. RAG Applications"
    / "data"
)
CHROMA_DB = str(PROJECT_ROOT / "storage" / "chroma_db")
COLLECTION_NAME = "financial_docs"
EMBEDDING_MODEL = "nomic-embed-text"
BASE_URL = "http://localhost:11434"

# %%
embedding_model = create_embedding_model(
    model_name=EMBEDDING_MODEL,
    base_url=BASE_URL,
)
vector_store = create_vector_store(
    embedding_model=embedding_model,
    persist_directory=CHROMA_DB,
    collection_name=COLLECTION_NAME,
)

# %%
sample_metadata = extract_metadata_from_filename("amazon 10-k 2024.pdf")
sample_metadata

# %%
# Replace with a real PDF path to test a single document.
# pdf_path = DATA_DIRECTORY / "amazon 10-k 2024.pdf"
# extract_pdf_page_wise(str(pdf_path))[:2]

# %%
# Replace with a real PDF path to ingest one file.
# result = embedding_ingestion_vector_db(vector_store, str(pdf_path))
# result

# %%
# Quick validation helpers.
# processed_hash(vector_store)
# run_pipeline_tests(vector_store=vector_store, data_directory=DATA_DIRECTORY)
